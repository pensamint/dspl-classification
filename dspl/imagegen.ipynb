# %%
import deeplenstronomy.deeplenstronomy as dl
from deeplenstronomy.visualize import view_image, view_image_rgb

# %%
ls
# Out:
# config.yaml  data/  ExampleDataset/  imagegen.ipynb  lsst_config.yaml

# %%
cd deeplenstronomy/dspl
# Out:
# [Errno 2] No such file or directory: 'deeplenstronomy/dspl'
# /home/belle/_dspl-classification/deeplenstronomy/dspl

# %%
dataset = dl.make_dataset('config.yaml', survey = 'lsst', verbose = True)
# Out:
# Entering main organization loop
# Organizing CONFIGURATION_1
# Generating images for CONFIGURATION_1
# 	Progress: 100.0 %  ---  Elapsed Time: 0 H 0 M 1 S

# %%
for i in range(5):
    view_image(dataset.CONFIGURATION_1_images[i])
