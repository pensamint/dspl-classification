# %% [markdown]
# # Generating Datasets
#
# A DeepLenstronomy Demo.
#
# `deeplenstronomy` is a software package that let's you interact with the strong gravitational lensing simulation software `lenstronomy` in a streamlined framework. Let's take a look at how it works!

# %%
import deeplenstronomy.deeplenstronomy as dl

# %% [markdown]
# `deeplenstronomy` works by reading user-prepared configuration files. start by specifying the configuration file you will use to make the dataset.

# %%
config_file = 'data/demo.yaml'

# %% [markdown]
# The configuration file is a yaml-style file for specifying all the properties of your dataset. Here is what this file contains:

# %%
! cat data/demo.yaml
# Out:
# DATASET:
#     NAME: MyDeeplenstronomyDataset
#     PARAMETERS:
#         SIZE: 100
#         OUTDIR: MySimulationResults2
#
# COSMOLOGY:
#     PARAMETERS:
#         H0: 70
#         Om0: 0.3
#
# IMAGE:
#     PARAMETERS:
#         exposure_time: 90
#         numPix: 100
#         pixel_scale: 0.263
#         psf_type: 'GAUSSIAN'
#         read_noise: 7
#         ccd_gain: 6.083
#
# SURVEY:
#     PARAMETERS:
#         BANDS: g,r,i,z,Y
#         seeing: 0.9
#         magnitude_zero_point: 30.0
#         sky_brightness: 23.5
#         num_exposures: 10
#
# SPECIES:
#     GALAXY_1:
#         NAME: LENS
#         LIGHT_PROFILE_1:
#             NAME: SERSIC_ELLIPSE
#             PARAMETERS:
#                 magnitude: 19.5
#                 center_x: 0.0
#                 center_y: 0.0
#                 R_sersic: 10
#                 n_sersic: 4
#                 e1: 0.2
#                 e2: -0.1
#         LIGHT_PROFILE_2:
#             NAME: SERSIC_ELLIPSE
#             PARAMETERS:
#                 magnitude: 18.0
#                 center_x: 0.0
#                 center_y: 0.0
#                 R_sersic: 3
#                 n_sersic: 8
#                 e1: 0.05
#                 e2: -0.05
#         MASS_PROFILE_1:
#             NAME: SIE
#             PARAMETERS:
#                 theta_E: 1.0
#                 e1: 0.1
#                 e2: -0.1
#                 center_x: 0.0
#                 center_y: 0.0
#         SHEAR_PROFILE_1:
#             NAME: SHEAR
#             PARAMETERS:
#                 gamma1: 0.08
#                 gamma2: 0.01
#     GALAXY_2:
#         NAME: SOURCE
#         LIGHT_PROFILE_1:
#             NAME: SERSIC_ELLIPSE
#             PARAMETERS:
#                 magnitude: 21.5
#                 center_x: 0.0
#                 center_y: 0.0
#                 R_sersic: 6
#                 n_sersic: 5
#                 e1: 0.2
#                 e2: -0.1
#         MASS_PROFILE_1:
#             NAME: SIE
#             PARAMETERS:
#                 theta_E: 1.0
#                 e1: 0.1
#                 e2: -0.1
#                 center_x: 0.0
#                 center_y: 0.0
#         SHEAR_PROFILE_1:
#             NAME: SHEAR
#             PARAMETERS:
#                 gamma1: 0.08
#                 gamma2: 0.01
#     POINTSOURCE_1:
#         NAME: AGN
#         HOST: SOURCE
#         PARAMETERS:
#             magnitude: 16
#     POINTSOURCE_2:
#         NAME: SUPERNOVA
#         HOST: SOURCE
#         PARAMETERS:
#             magnitude: 21.0
#             sep: 2.0
#             sep_unit: arcsec
#     POINTSOURCE_3:
#         NAME: STAR
#         HOST: Foreground
#         PARAMETERS:
#             magnitude: 14.0
#     NOISE_1:
#         NAME: POISSON_NOISE
#         PARAMETERS:
#             mean: 2.0
#
#
# GEOMETRY:
#     CONFIGURATION_1:
#         NAME: GALAXY_AGN
#         FRACTION: 0.25
#         PLANE_1:
#             OBJECT_1: LENS
#             PARAMETERS:
#                 REDSHIFT: 0.2
#         PLANE_2:
#             OBJECT_1: SOURCE
#             OBJECT_2: AGN
#             PARAMETERS:
#                 REDSHIFT: 0.7
#         NOISE_SOURCE_1: POISSON_NOISE
#
#
#     CONFIGURATION_2:
#         NAME: GALAXY_AGN_NOISELESS
#         FRACTION: 0.25
#         PLANE_1:
#             OBJECT_1: LENS
#             PARAMETERS:
#                 REDSHIFT: 0.2
#         PLANE_2:
#             OBJECT_1: SOURCE
#             OBJECT_2: AGN
#             PARAMETERS:
#                 REDSHIFT: 0.7
#
#     CONFIGURATION_3:
#         NAME: LENSED_SNE
#         FRACTION: 0.25
#         PLANE_1:
#             OBJECT_1: LENS
#             PARAMETERS:
#                 REDSHIFT: 0.2
#         PLANE_2:
#             OBJECT_1: SOURCE
#             OBJECT_2: SUPERNOVA
#             PARAMETERS:
#                 REDSHIFT: 0.7
#         NOISE_SOURCE_1: POISSON_NOISE
#
#     CONFIGURATION_4:
#         NAME: SPICY_LIFE
#         FRACTION: 0.25
#         PLANE_1:
#             OBJECT_1: LENS
#             OBJECT_2: STAR
#             OBJECT_3: STAR
#             PARAMETERS:
#                 REDSHIFT: 0.2
#         PLANE_2:
#             OBJECT_1: LENS
#             PARAMETERS:
#                 REDSHIFT: 0.7
#         PLANE_3:
#             OBJECT_1: SOURCE
#             OBJECT_2: SUPERNOVA
#             OBJECT_3: AGN
#             PARAMETERS:
#                 REDSHIFT: 1.3
#         NOISE_SOURCE_1: POISSON_NOISE

# %% [markdown]
# There's a lot of information in there. To learn about how configuration files for `deeplenstronomy` are structured, check out the [Creating `deeplenstronomy` Configuration Files](https://github.com/rmorgan10/deeplenstronomy/blob/master/Notebooks/ConfigFiles.md) documentation.

# %% [markdown]
# ## Simulating a Dataset
#
# Let's put `deeplenstronomy` to work!

# %%
dataset = dl.make_dataset(config_file, verbose = True)
# Out:
# Entering main organization loop
# Organizing CONFIGURATION_1
# Organizing CONFIGURATION_2
# Organizing CONFIGURATION_3
# Organizing CONFIGURATION_4
# Generating images for CONFIGURATION_1
# 	Progress: 100.0 %  ---  Elapsed Time: 0 H 0 M 1 S
# Generating images for CONFIGURATION_2
# 	Progress: 100.0 %  ---  Elapsed Time: 0 H 0 M 1 S
# Generating images for CONFIGURATION_3
# 	Progress: 100.0 %  ---  Elapsed Time: 0 H 0 M 0 S
# Generating images for CONFIGURATION_4
# 	Progress: 100.0 %  ---  Elapsed Time: 0 H 0 M 1 S

# %% [markdown]
# That's it. You now have your dataset.

# %% [markdown]
# ## Understanding the `make_dataset()` Function
#
# All the information about the contents of the dataset is stored in the configuration file, but the `make_dataset()` function will tell `deeplenstronomy` what you want to do with your dataset.
# Let's look at the function definition:
#
# ```python
# def make_dataset(config, dataset=None, save_to_disk=False, store_in_memory=True,
#                  verbose=False, store_sample=False, image_file_format='npy',
#                  survey=None, return_planes=False, skip_image_generation=False,
#                  solve_lens_equation=False):
#     """
#     Generate a dataset from a config file
#
#     :param config: yaml file specifying dataset characteristics
#                    OR
#                    pre-parsed yaml file as a dictionary
#     :param verbose: bool, if true, print status updates
#     :param store_in_memory: bool, save images and metadata as attributes
#     :param save_to_disk: bool, save images and metadata to disk
#     :param store_sample: bool, save five images and metadata as attribute
#     :param image_file_format: outfile format type (npy, h5)
#     :param survey: str, a default astronomical survey to use
#     :param return_planes: bool, if true, return the separate planes of simulated images
#     :param skip_image_generation: bool, if true, skip image generation
#     :param solve_lens_equation: bool, if true, calculate the source positions
#     :return: dataset: instance of dataset class
#     """
# ```
#
# If all the default parameters work for you, then all you have to do is call `dataset = dl.make_dataset(config_file)` and you'll be good to go. If not, the parameters can be modified to product the desired behavior.
#
# ### `make_dataset()` Parameters:
#
# - config
#
# The filename of your configuration file as a string.
#
# - verbose
#
# If you would like brief status messages of the simulation to be printed as `make_dataset()` runs, you can set `verbose=True`.
#
# - store_in_memory
#
# By default, the simulated images and associated metadata will be stored in your computer's memory as attributes of the object returned by `make_dataset()`. If you would like to prevent this, typically motivated by just wanting to write the simulation products directly to output files, you can pass `store_in_memory=False`.
#
# - save_to_disk
#
# By default, the simulated images and associated metadata are not saved to output files. If you would like them to be saved, set `save_to_disk=True` and make sure to specify an out directory in your configuration file.
#
# - store_sample
#
# If you would like to take a peek at the simualted images and metadata to inspect them without storing the entire dataset in memory, you can set `store_sample=True`. This setting will store five images for each configuration in memory as attributes of the object returned by `make_dataset()`.
#
# - image_file_format
#
# When saving images to disk, you can choose the image file format. The currently supported options are (by default) `image_file_format='npy'` and `image_file_format='h5'`.
#
# - survey
#
# `deeplenstronomy` has built in information about multiple large astronomical surveys. Currently, the options are `des`, `delve`, `lsst`, `ztf`, `euclid`, and `hst`. Specifying one of these will overwrite values of the `SURVEY` and `IMAGE` sections of your configuration file at runtime.
#
# - return_planes
#
# By default, `deeplenstronomy` will calculate light from lenses, sources, point sources, and noise separately before stacking them into one output image. If you would prefer to keep the lens, source, point source, and noise information separate for your analysis, you can pass `return_planes=True`. The image arrays in your dataset will gain an extra dimension of length 4 (one for each of these possible sources of light).
#
# - skip_image_generation
#
# If you would like to generate all the `lenstronomy` inputs specified in you configuration file but not generate images, for example to check that your distribtuions are working as expected, you can skip the image generation step while still outputing all the metadata by setting `skip_image_generation=True`.
#
# - solve_lens_equation
#
# If you would like to analyze the positions and numbers of individual images of the source galaxy in each of your dataset images you will need to solve the lens equation. To do this, set `solve_lens_equation=True` and this information will be calculated and sotred in the metadata. This calculation is skipped by default for performance considerations.

# %% [markdown]
# ## Interacting with the Dataset
#
# Now that we have a dataset, let's look at what was stored in the `dataset` variable.
#
# The configuration labels you specified in the configuration file are stored here. The reasoning here is if you plan to do some sort of supervised classification, you will probably want to have the images labeled.

# %%
print(dataset.configurations)
# Out:
# ['CONFIGURATION_1', 'CONFIGURATION_2', 'CONFIGURATION_3', 'CONFIGURATION_4']

# %% [markdown]
# The dataset name, size, and output directory are also stored as attributes of the dataset object.

# %%
print(dataset.name)
print(dataset.size)
print(dataset.outdir)
# Out:
# MyDeeplenstronomyDataset
# 100
# MySimulationResults2

# %% [markdown]
# There are a few other things that get stored automatically (that you can explore via `dir(dataset)`), but we'll shift our focus to the things we simulated.
#
# The most interesting information is stored here in these attributes:

# %%
for item in [x for x in dir(dataset) if x[0:13] == 'CONFIGURATION']:
    print(item)
# Out:
# CONFIGURATION_1_images
# CONFIGURATION_1_metadata
# CONFIGURATION_2_images
# CONFIGURATION_2_metadata
# CONFIGURATION_3_images
# CONFIGURATION_3_metadata
# CONFIGURATION_4_images
# CONFIGURATION_4_metadata

# %% [markdown]
# The `_images` attribute is a `numpy.ndarray` object and the `_metadata` attribute is a `pandas.DataFrame` object.

# %%
print(type(dataset.CONFIGURATION_1_images))
print(type(dataset.CONFIGURATION_1_metadata))
# Out:
# <class 'numpy.ndarray'>
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ### Images
#
# Let's checkout some of the images in the `dataset.CONFIGURATION_1_images` attribute.
#
# What's in this array?

# %%
print(dataset.CONFIGURATION_1_images.shape)
# Out:
# (24, 5, 100, 100)

# %% [markdown]
# The array dimensions are (image index, band, x_pixels, y_pixels).
#
# The number of images is the size of the dataset multiplied by the fraction of the dataset in CONFIGURATION_1, both of which you specify in the configuration file. The bands used is also specified in the configuration file. Finally, yup you guessed it, the image dimensions are also specified in the configuration file.

# %% [markdown]
# `deeplenstronomy` also has built-in vizualization functions that are demonstrated in more detail in the Visualization Notebook.
#
# Let's look at the r-band of image index 2 in CONFIGURATION_1:

# %%
from deeplenstronomy.visualize import view_image

# %%
view_image(dataset.CONFIGURATION_1_images[2][1])

# %% [markdown]
# You can also look at all the bands for this image at once.

# %%
view_image(dataset.CONFIGURATION_1_images[2])

# %% [markdown]
# ### Metadata
#
# Once you have an image, you may want to consider the parameters that went into its generation to better understand what you made. To check that out, you can view the metadata saved by `deeplenstronomy`.
#
# Let's look at the properties of the metadata.

# %%
dataset.CONFIGURATION_1_metadata.shape
# Out:
# (24, 445)

# %% [markdown]
# Wow. That's a lot of columns. The number of columns increases with the complexity of your configurations, since there is more information for `deeplenstronomy` to keep track of. The columns are also broken up my band, so doubling the number of bands will double the number of columns in the metadata.
#
# Let's look at the column names to see what information we have.

# %%
for col in dataset.CONFIGURATION_1_metadata.columns:
    print(col)
# Out:
# OBJID-g
# H0-g
# Om0-g
# exposure_time-g
# numPix-g
# pixel_scale-g
# psf_type-g
# read_noise-g
# ccd_gain-g
# seeing-g
# magnitude_zero_point-g
# sky_brightness-g
# num_exposures-g
# NUMBER_OF_NOISE_SOURCES-g
# NOISE_SOURCE_1-NAME-g
# NOISE_SOURCE_1-mean-g
# CONFIGURATION_LABEL-g
# CONFIGURATION_NAME-g
# NUMBER_OF_PLANES-g
# PLANE_1-NUMBER_OF_OBJECTS-g
# PLANE_1-OBJECT_1-NAME-g
# PLANE_2-NUMBER_OF_OBJECTS-g
# PLANE_2-OBJECT_1-NAME-g
# PLANE_2-OBJECT_2-NAME-g
# PLANE_1-OBJECT_1-REDSHIFT-g
# PLANE_1-OBJECT_1-NUMBER_OF_LIGHT_PROFILES-g
# PLANE_1-OBJECT_1-NUMBER_OF_SHEAR_PROFILES-g
# PLANE_1-OBJECT_1-NUMBER_OF_MASS_PROFILES-g
# PLANE_1-OBJECT_1-HOST-g
# PLANE_1-OBJECT_1-LIGHT_PROFILE_1-NAME-g
# PLANE_1-OBJECT_1-LIGHT_PROFILE_1-magnitude-g
# PLANE_1-OBJECT_1-LIGHT_PROFILE_1-center_x-g
# PLANE_1-OBJECT_1-LIGHT_PROFILE_1-center_y-g
# PLANE_1-OBJECT_1-LIGHT_PROFILE_1-R_sersic-g
# PLANE_1-OBJECT_1-LIGHT_PROFILE_1-n_sersic-g
# PLANE_1-OBJECT_1-LIGHT_PROFILE_1-e1-g
# PLANE_1-OBJECT_1-LIGHT_PROFILE_1-e2-g
# PLANE_1-OBJECT_1-LIGHT_PROFILE_2-NAME-g
# PLANE_1-OBJECT_1-LIGHT_PROFILE_2-magnitude-g
# PLANE_1-OBJECT_1-LIGHT_PROFILE_2-center_x-g
# PLANE_1-OBJECT_1-LIGHT_PROFILE_2-center_y-g
# PLANE_1-OBJECT_1-LIGHT_PROFILE_2-R_sersic-g
# PLANE_1-OBJECT_1-LIGHT_PROFILE_2-n_sersic-g
# PLANE_1-OBJECT_1-LIGHT_PROFILE_2-e1-g
# PLANE_1-OBJECT_1-LIGHT_PROFILE_2-e2-g
# PLANE_1-OBJECT_1-MASS_PROFILE_1-NAME-g
# PLANE_1-OBJECT_1-MASS_PROFILE_1-theta_E-g
# PLANE_1-OBJECT_1-MASS_PROFILE_1-e1-g
# PLANE_1-OBJECT_1-MASS_PROFILE_1-e2-g
# PLANE_1-OBJECT_1-MASS_PROFILE_1-center_x-g
# PLANE_1-OBJECT_1-MASS_PROFILE_1-center_y-g
# PLANE_1-OBJECT_1-SHEAR_PROFILE_1-NAME-g
# PLANE_1-OBJECT_1-SHEAR_PROFILE_1-gamma1-g
# PLANE_1-OBJECT_1-SHEAR_PROFILE_1-gamma2-g
# PLANE_2-OBJECT_1-REDSHIFT-g
# PLANE_2-OBJECT_2-REDSHIFT-g
# PLANE_2-OBJECT_1-NUMBER_OF_LIGHT_PROFILES-g
# PLANE_2-OBJECT_1-NUMBER_OF_SHEAR_PROFILES-g
# PLANE_2-OBJECT_1-NUMBER_OF_MASS_PROFILES-g
# PLANE_2-OBJECT_1-HOST-g
# PLANE_2-OBJECT_1-LIGHT_PROFILE_1-NAME-g
# PLANE_2-OBJECT_1-LIGHT_PROFILE_1-magnitude-g
# PLANE_2-OBJECT_1-LIGHT_PROFILE_1-center_x-g
# PLANE_2-OBJECT_1-LIGHT_PROFILE_1-center_y-g
# PLANE_2-OBJECT_1-LIGHT_PROFILE_1-R_sersic-g
# PLANE_2-OBJECT_1-LIGHT_PROFILE_1-n_sersic-g
# PLANE_2-OBJECT_1-LIGHT_PROFILE_1-e1-g
# PLANE_2-OBJECT_1-LIGHT_PROFILE_1-e2-g
# PLANE_2-OBJECT_1-MASS_PROFILE_1-NAME-g
# PLANE_2-OBJECT_1-MASS_PROFILE_1-theta_E-g
# PLANE_2-OBJECT_1-MASS_PROFILE_1-e1-g
# PLANE_2-OBJECT_1-MASS_PROFILE_1-e2-g
# PLANE_2-OBJECT_1-MASS_PROFILE_1-center_x-g
# PLANE_2-OBJECT_1-MASS_PROFILE_1-center_y-g
# PLANE_2-OBJECT_1-SHEAR_PROFILE_1-NAME-g
# PLANE_2-OBJECT_1-SHEAR_PROFILE_1-gamma1-g
# PLANE_2-OBJECT_1-SHEAR_PROFILE_1-gamma2-g
# PLANE_2-OBJECT_2-NUMBER_OF_LIGHT_PROFILES-g
# PLANE_2-OBJECT_2-NUMBER_OF_SHEAR_PROFILES-g
# PLANE_2-OBJECT_2-NUMBER_OF_MASS_PROFILES-g
# PLANE_2-OBJECT_2-HOST-g
# PLANE_2-OBJECT_2-ra-g
# PLANE_2-OBJECT_2-dec-g
# PLANE_2-OBJECT_2-sep-g
# PLANE_2-OBJECT_2-sep_unit-g
# PLANE_2-OBJECT_2-magnitude-g
# BACKGROUND_IDX-g
# OBJID-r
# H0-r
# Om0-r
# exposure_time-r
# numPix-r
# pixel_scale-r
# psf_type-r
# read_noise-r
# ccd_gain-r
# seeing-r
# magnitude_zero_point-r
# sky_brightness-r
# num_exposures-r
# NUMBER_OF_NOISE_SOURCES-r
# NOISE_SOURCE_1-NAME-r
# NOISE_SOURCE_1-mean-r
# CONFIGURATION_LABEL-r
# CONFIGURATION_NAME-r
# NUMBER_OF_PLANES-r
# PLANE_1-NUMBER_OF_OBJECTS-r
# PLANE_1-OBJECT_1-NAME-r
# PLANE_2-NUMBER_OF_OBJECTS-r
# PLANE_2-OBJECT_1-NAME-r
# PLANE_2-OBJECT_2-NAME-r
# PLANE_1-OBJECT_1-REDSHIFT-r
# PLANE_1-OBJECT_1-NUMBER_OF_LIGHT_PROFILES-r
# PLANE_1-OBJECT_1-NUMBER_OF_SHEAR_PROFILES-r
# PLANE_1-OBJECT_1-NUMBER_OF_MASS_PROFILES-r
# PLANE_1-OBJECT_1-HOST-r
# PLANE_1-OBJECT_1-LIGHT_PROFILE_1-NAME-r
# PLANE_1-OBJECT_1-LIGHT_PROFILE_1-magnitude-r
# PLANE_1-OBJECT_1-LIGHT_PROFILE_1-center_x-r
# PLANE_1-OBJECT_1-LIGHT_PROFILE_1-center_y-r
# PLANE_1-OBJECT_1-LIGHT_PROFILE_1-R_sersic-r
# PLANE_1-OBJECT_1-LIGHT_PROFILE_1-n_sersic-r
# PLANE_1-OBJECT_1-LIGHT_PROFILE_1-e1-r
# PLANE_1-OBJECT_1-LIGHT_PROFILE_1-e2-r
# PLANE_1-OBJECT_1-LIGHT_PROFILE_2-NAME-r
# PLANE_1-OBJECT_1-LIGHT_PROFILE_2-magnitude-r
# PLANE_1-OBJECT_1-LIGHT_PROFILE_2-center_x-r
# PLANE_1-OBJECT_1-LIGHT_PROFILE_2-center_y-r
# PLANE_1-OBJECT_1-LIGHT_PROFILE_2-R_sersic-r
# PLANE_1-OBJECT_1-LIGHT_PROFILE_2-n_sersic-r
# PLANE_1-OBJECT_1-LIGHT_PROFILE_2-e1-r
# PLANE_1-OBJECT_1-LIGHT_PROFILE_2-e2-r
# PLANE_1-OBJECT_1-MASS_PROFILE_1-NAME-r
# PLANE_1-OBJECT_1-MASS_PROFILE_1-theta_E-r
# PLANE_1-OBJECT_1-MASS_PROFILE_1-e1-r
# PLANE_1-OBJECT_1-MASS_PROFILE_1-e2-r
# PLANE_1-OBJECT_1-MASS_PROFILE_1-center_x-r
# PLANE_1-OBJECT_1-MASS_PROFILE_1-center_y-r
# PLANE_1-OBJECT_1-SHEAR_PROFILE_1-NAME-r
# PLANE_1-OBJECT_1-SHEAR_PROFILE_1-gamma1-r
# PLANE_1-OBJECT_1-SHEAR_PROFILE_1-gamma2-r
# PLANE_2-OBJECT_1-REDSHIFT-r
# PLANE_2-OBJECT_2-REDSHIFT-r
# PLANE_2-OBJECT_1-NUMBER_OF_LIGHT_PROFILES-r
# PLANE_2-OBJECT_1-NUMBER_OF_SHEAR_PROFILES-r
# PLANE_2-OBJECT_1-NUMBER_OF_MASS_PROFILES-r
# PLANE_2-OBJECT_1-HOST-r
# PLANE_2-OBJECT_1-LIGHT_PROFILE_1-NAME-r
# PLANE_2-OBJECT_1-LIGHT_PROFILE_1-magnitude-r
# PLANE_2-OBJECT_1-LIGHT_PROFILE_1-center_x-r
# PLANE_2-OBJECT_1-LIGHT_PROFILE_1-center_y-r
# PLANE_2-OBJECT_1-LIGHT_PROFILE_1-R_sersic-r
# PLANE_2-OBJECT_1-LIGHT_PROFILE_1-n_sersic-r
# PLANE_2-OBJECT_1-LIGHT_PROFILE_1-e1-r
# PLANE_2-OBJECT_1-LIGHT_PROFILE_1-e2-r
# PLANE_2-OBJECT_1-MASS_PROFILE_1-NAME-r
# PLANE_2-OBJECT_1-MASS_PROFILE_1-theta_E-r
# PLANE_2-OBJECT_1-MASS_PROFILE_1-e1-r
# PLANE_2-OBJECT_1-MASS_PROFILE_1-e2-r
# PLANE_2-OBJECT_1-MASS_PROFILE_1-center_x-r
# PLANE_2-OBJECT_1-MASS_PROFILE_1-center_y-r
# PLANE_2-OBJECT_1-SHEAR_PROFILE_1-NAME-r
# PLANE_2-OBJECT_1-SHEAR_PROFILE_1-gamma1-r
# PLANE_2-OBJECT_1-SHEAR_PROFILE_1-gamma2-r
# PLANE_2-OBJECT_2-NUMBER_OF_LIGHT_PROFILES-r
# PLANE_2-OBJECT_2-NUMBER_OF_SHEAR_PROFILES-r
# PLANE_2-OBJECT_2-NUMBER_OF_MASS_PROFILES-r
# PLANE_2-OBJECT_2-HOST-r
# PLANE_2-OBJECT_2-ra-r
# PLANE_2-OBJECT_2-dec-r
# PLANE_2-OBJECT_2-sep-r
# PLANE_2-OBJECT_2-sep_unit-r
# PLANE_2-OBJECT_2-magnitude-r
# BACKGROUND_IDX-r
# OBJID-i
# H0-i
# Om0-i
# exposure_time-i
# numPix-i
# pixel_scale-i
# psf_type-i
# read_noise-i
# ccd_gain-i
# seeing-i
# magnitude_zero_point-i
# sky_brightness-i
# num_exposures-i
# NUMBER_OF_NOISE_SOURCES-i
# NOISE_SOURCE_1-NAME-i
# NOISE_SOURCE_1-mean-i
# CONFIGURATION_LABEL-i
# CONFIGURATION_NAME-i
# NUMBER_OF_PLANES-i
# PLANE_1-NUMBER_OF_OBJECTS-i
# PLANE_1-OBJECT_1-NAME-i
# PLANE_2-NUMBER_OF_OBJECTS-i
# PLANE_2-OBJECT_1-NAME-i
# PLANE_2-OBJECT_2-NAME-i
# PLANE_1-OBJECT_1-REDSHIFT-i
# PLANE_1-OBJECT_1-NUMBER_OF_LIGHT_PROFILES-i
# PLANE_1-OBJECT_1-NUMBER_OF_SHEAR_PROFILES-i
# PLANE_1-OBJECT_1-NUMBER_OF_MASS_PROFILES-i
# PLANE_1-OBJECT_1-HOST-i
# PLANE_1-OBJECT_1-LIGHT_PROFILE_1-NAME-i
# PLANE_1-OBJECT_1-LIGHT_PROFILE_1-magnitude-i
# PLANE_1-OBJECT_1-LIGHT_PROFILE_1-center_x-i
# PLANE_1-OBJECT_1-LIGHT_PROFILE_1-center_y-i
# PLANE_1-OBJECT_1-LIGHT_PROFILE_1-R_sersic-i
# PLANE_1-OBJECT_1-LIGHT_PROFILE_1-n_sersic-i
# PLANE_1-OBJECT_1-LIGHT_PROFILE_1-e1-i
# PLANE_1-OBJECT_1-LIGHT_PROFILE_1-e2-i
# PLANE_1-OBJECT_1-LIGHT_PROFILE_2-NAME-i
# PLANE_1-OBJECT_1-LIGHT_PROFILE_2-magnitude-i
# PLANE_1-OBJECT_1-LIGHT_PROFILE_2-center_x-i
# PLANE_1-OBJECT_1-LIGHT_PROFILE_2-center_y-i
# PLANE_1-OBJECT_1-LIGHT_PROFILE_2-R_sersic-i
# PLANE_1-OBJECT_1-LIGHT_PROFILE_2-n_sersic-i
# PLANE_1-OBJECT_1-LIGHT_PROFILE_2-e1-i
# PLANE_1-OBJECT_1-LIGHT_PROFILE_2-e2-i
# PLANE_1-OBJECT_1-MASS_PROFILE_1-NAME-i
# PLANE_1-OBJECT_1-MASS_PROFILE_1-theta_E-i
# PLANE_1-OBJECT_1-MASS_PROFILE_1-e1-i
# PLANE_1-OBJECT_1-MASS_PROFILE_1-e2-i
# PLANE_1-OBJECT_1-MASS_PROFILE_1-center_x-i
# PLANE_1-OBJECT_1-MASS_PROFILE_1-center_y-i
# PLANE_1-OBJECT_1-SHEAR_PROFILE_1-NAME-i
# PLANE_1-OBJECT_1-SHEAR_PROFILE_1-gamma1-i
# PLANE_1-OBJECT_1-SHEAR_PROFILE_1-gamma2-i
# PLANE_2-OBJECT_1-REDSHIFT-i
# PLANE_2-OBJECT_2-REDSHIFT-i
# PLANE_2-OBJECT_1-NUMBER_OF_LIGHT_PROFILES-i
# PLANE_2-OBJECT_1-NUMBER_OF_SHEAR_PROFILES-i
# PLANE_2-OBJECT_1-NUMBER_OF_MASS_PROFILES-i
# PLANE_2-OBJECT_1-HOST-i
# PLANE_2-OBJECT_1-LIGHT_PROFILE_1-NAME-i
# PLANE_2-OBJECT_1-LIGHT_PROFILE_1-magnitude-i
# PLANE_2-OBJECT_1-LIGHT_PROFILE_1-center_x-i
# PLANE_2-OBJECT_1-LIGHT_PROFILE_1-center_y-i
# PLANE_2-OBJECT_1-LIGHT_PROFILE_1-R_sersic-i
# PLANE_2-OBJECT_1-LIGHT_PROFILE_1-n_sersic-i
# PLANE_2-OBJECT_1-LIGHT_PROFILE_1-e1-i
# PLANE_2-OBJECT_1-LIGHT_PROFILE_1-e2-i
# PLANE_2-OBJECT_1-MASS_PROFILE_1-NAME-i
# PLANE_2-OBJECT_1-MASS_PROFILE_1-theta_E-i
# PLANE_2-OBJECT_1-MASS_PROFILE_1-e1-i
# PLANE_2-OBJECT_1-MASS_PROFILE_1-e2-i
# PLANE_2-OBJECT_1-MASS_PROFILE_1-center_x-i
# PLANE_2-OBJECT_1-MASS_PROFILE_1-center_y-i
# PLANE_2-OBJECT_1-SHEAR_PROFILE_1-NAME-i
# PLANE_2-OBJECT_1-SHEAR_PROFILE_1-gamma1-i
# PLANE_2-OBJECT_1-SHEAR_PROFILE_1-gamma2-i
# PLANE_2-OBJECT_2-NUMBER_OF_LIGHT_PROFILES-i
# PLANE_2-OBJECT_2-NUMBER_OF_SHEAR_PROFILES-i
# PLANE_2-OBJECT_2-NUMBER_OF_MASS_PROFILES-i
# PLANE_2-OBJECT_2-HOST-i
# PLANE_2-OBJECT_2-ra-i
# PLANE_2-OBJECT_2-dec-i
# PLANE_2-OBJECT_2-sep-i
# PLANE_2-OBJECT_2-sep_unit-i
# PLANE_2-OBJECT_2-magnitude-i
# BACKGROUND_IDX-i
# OBJID-z
# H0-z
# Om0-z
# exposure_time-z
# numPix-z
# pixel_scale-z
# psf_type-z
# read_noise-z
# ccd_gain-z
# seeing-z
# magnitude_zero_point-z
# sky_brightness-z
# num_exposures-z
# NUMBER_OF_NOISE_SOURCES-z
# NOISE_SOURCE_1-NAME-z
# NOISE_SOURCE_1-mean-z
# CONFIGURATION_LABEL-z
# CONFIGURATION_NAME-z
# NUMBER_OF_PLANES-z
# PLANE_1-NUMBER_OF_OBJECTS-z
# PLANE_1-OBJECT_1-NAME-z
# PLANE_2-NUMBER_OF_OBJECTS-z
# PLANE_2-OBJECT_1-NAME-z
# PLANE_2-OBJECT_2-NAME-z
# PLANE_1-OBJECT_1-REDSHIFT-z
# PLANE_1-OBJECT_1-NUMBER_OF_LIGHT_PROFILES-z
# PLANE_1-OBJECT_1-NUMBER_OF_SHEAR_PROFILES-z
# PLANE_1-OBJECT_1-NUMBER_OF_MASS_PROFILES-z
# PLANE_1-OBJECT_1-HOST-z
# PLANE_1-OBJECT_1-LIGHT_PROFILE_1-NAME-z
# PLANE_1-OBJECT_1-LIGHT_PROFILE_1-magnitude-z
# PLANE_1-OBJECT_1-LIGHT_PROFILE_1-center_x-z
# PLANE_1-OBJECT_1-LIGHT_PROFILE_1-center_y-z
# PLANE_1-OBJECT_1-LIGHT_PROFILE_1-R_sersic-z
# PLANE_1-OBJECT_1-LIGHT_PROFILE_1-n_sersic-z
# PLANE_1-OBJECT_1-LIGHT_PROFILE_1-e1-z
# PLANE_1-OBJECT_1-LIGHT_PROFILE_1-e2-z
# PLANE_1-OBJECT_1-LIGHT_PROFILE_2-NAME-z
# PLANE_1-OBJECT_1-LIGHT_PROFILE_2-magnitude-z
# PLANE_1-OBJECT_1-LIGHT_PROFILE_2-center_x-z
# PLANE_1-OBJECT_1-LIGHT_PROFILE_2-center_y-z
# PLANE_1-OBJECT_1-LIGHT_PROFILE_2-R_sersic-z
# PLANE_1-OBJECT_1-LIGHT_PROFILE_2-n_sersic-z
# PLANE_1-OBJECT_1-LIGHT_PROFILE_2-e1-z
# PLANE_1-OBJECT_1-LIGHT_PROFILE_2-e2-z
# PLANE_1-OBJECT_1-MASS_PROFILE_1-NAME-z
# PLANE_1-OBJECT_1-MASS_PROFILE_1-theta_E-z
# PLANE_1-OBJECT_1-MASS_PROFILE_1-e1-z
# PLANE_1-OBJECT_1-MASS_PROFILE_1-e2-z
# PLANE_1-OBJECT_1-MASS_PROFILE_1-center_x-z
# PLANE_1-OBJECT_1-MASS_PROFILE_1-center_y-z
# PLANE_1-OBJECT_1-SHEAR_PROFILE_1-NAME-z
# PLANE_1-OBJECT_1-SHEAR_PROFILE_1-gamma1-z
# PLANE_1-OBJECT_1-SHEAR_PROFILE_1-gamma2-z
# PLANE_2-OBJECT_1-REDSHIFT-z
# PLANE_2-OBJECT_2-REDSHIFT-z
# PLANE_2-OBJECT_1-NUMBER_OF_LIGHT_PROFILES-z
# PLANE_2-OBJECT_1-NUMBER_OF_SHEAR_PROFILES-z
# PLANE_2-OBJECT_1-NUMBER_OF_MASS_PROFILES-z
# PLANE_2-OBJECT_1-HOST-z
# PLANE_2-OBJECT_1-LIGHT_PROFILE_1-NAME-z
# PLANE_2-OBJECT_1-LIGHT_PROFILE_1-magnitude-z
# PLANE_2-OBJECT_1-LIGHT_PROFILE_1-center_x-z
# PLANE_2-OBJECT_1-LIGHT_PROFILE_1-center_y-z
# PLANE_2-OBJECT_1-LIGHT_PROFILE_1-R_sersic-z
# PLANE_2-OBJECT_1-LIGHT_PROFILE_1-n_sersic-z
# PLANE_2-OBJECT_1-LIGHT_PROFILE_1-e1-z
# PLANE_2-OBJECT_1-LIGHT_PROFILE_1-e2-z
# PLANE_2-OBJECT_1-MASS_PROFILE_1-NAME-z
# PLANE_2-OBJECT_1-MASS_PROFILE_1-theta_E-z
# PLANE_2-OBJECT_1-MASS_PROFILE_1-e1-z
# PLANE_2-OBJECT_1-MASS_PROFILE_1-e2-z
# PLANE_2-OBJECT_1-MASS_PROFILE_1-center_x-z
# PLANE_2-OBJECT_1-MASS_PROFILE_1-center_y-z
# PLANE_2-OBJECT_1-SHEAR_PROFILE_1-NAME-z
# PLANE_2-OBJECT_1-SHEAR_PROFILE_1-gamma1-z
# PLANE_2-OBJECT_1-SHEAR_PROFILE_1-gamma2-z
# PLANE_2-OBJECT_2-NUMBER_OF_LIGHT_PROFILES-z
# PLANE_2-OBJECT_2-NUMBER_OF_SHEAR_PROFILES-z
# PLANE_2-OBJECT_2-NUMBER_OF_MASS_PROFILES-z
# PLANE_2-OBJECT_2-HOST-z
# PLANE_2-OBJECT_2-ra-z
# PLANE_2-OBJECT_2-dec-z
# PLANE_2-OBJECT_2-sep-z
# PLANE_2-OBJECT_2-sep_unit-z
# PLANE_2-OBJECT_2-magnitude-z
# BACKGROUND_IDX-z
# OBJID-Y
# H0-Y
# Om0-Y
# exposure_time-Y
# numPix-Y
# pixel_scale-Y
# psf_type-Y
# read_noise-Y
# ccd_gain-Y
# seeing-Y
# magnitude_zero_point-Y
# sky_brightness-Y
# num_exposures-Y
# NUMBER_OF_NOISE_SOURCES-Y
# NOISE_SOURCE_1-NAME-Y
# NOISE_SOURCE_1-mean-Y
# CONFIGURATION_LABEL-Y
# CONFIGURATION_NAME-Y
# NUMBER_OF_PLANES-Y
# PLANE_1-NUMBER_OF_OBJECTS-Y
# PLANE_1-OBJECT_1-NAME-Y
# PLANE_2-NUMBER_OF_OBJECTS-Y
# PLANE_2-OBJECT_1-NAME-Y
# PLANE_2-OBJECT_2-NAME-Y
# PLANE_1-OBJECT_1-REDSHIFT-Y
# PLANE_1-OBJECT_1-NUMBER_OF_LIGHT_PROFILES-Y
# PLANE_1-OBJECT_1-NUMBER_OF_SHEAR_PROFILES-Y
# PLANE_1-OBJECT_1-NUMBER_OF_MASS_PROFILES-Y
# PLANE_1-OBJECT_1-HOST-Y
# PLANE_1-OBJECT_1-LIGHT_PROFILE_1-NAME-Y
# PLANE_1-OBJECT_1-LIGHT_PROFILE_1-magnitude-Y
# PLANE_1-OBJECT_1-LIGHT_PROFILE_1-center_x-Y
# PLANE_1-OBJECT_1-LIGHT_PROFILE_1-center_y-Y
# PLANE_1-OBJECT_1-LIGHT_PROFILE_1-R_sersic-Y
# PLANE_1-OBJECT_1-LIGHT_PROFILE_1-n_sersic-Y
# PLANE_1-OBJECT_1-LIGHT_PROFILE_1-e1-Y
# PLANE_1-OBJECT_1-LIGHT_PROFILE_1-e2-Y
# PLANE_1-OBJECT_1-LIGHT_PROFILE_2-NAME-Y
# PLANE_1-OBJECT_1-LIGHT_PROFILE_2-magnitude-Y
# PLANE_1-OBJECT_1-LIGHT_PROFILE_2-center_x-Y
# PLANE_1-OBJECT_1-LIGHT_PROFILE_2-center_y-Y
# PLANE_1-OBJECT_1-LIGHT_PROFILE_2-R_sersic-Y
# PLANE_1-OBJECT_1-LIGHT_PROFILE_2-n_sersic-Y
# PLANE_1-OBJECT_1-LIGHT_PROFILE_2-e1-Y
# PLANE_1-OBJECT_1-LIGHT_PROFILE_2-e2-Y
# PLANE_1-OBJECT_1-MASS_PROFILE_1-NAME-Y
# PLANE_1-OBJECT_1-MASS_PROFILE_1-theta_E-Y
# PLANE_1-OBJECT_1-MASS_PROFILE_1-e1-Y
# PLANE_1-OBJECT_1-MASS_PROFILE_1-e2-Y
# PLANE_1-OBJECT_1-MASS_PROFILE_1-center_x-Y
# PLANE_1-OBJECT_1-MASS_PROFILE_1-center_y-Y
# PLANE_1-OBJECT_1-SHEAR_PROFILE_1-NAME-Y
# PLANE_1-OBJECT_1-SHEAR_PROFILE_1-gamma1-Y
# PLANE_1-OBJECT_1-SHEAR_PROFILE_1-gamma2-Y
# PLANE_2-OBJECT_1-REDSHIFT-Y
# PLANE_2-OBJECT_2-REDSHIFT-Y
# PLANE_2-OBJECT_1-NUMBER_OF_LIGHT_PROFILES-Y
# PLANE_2-OBJECT_1-NUMBER_OF_SHEAR_PROFILES-Y
# PLANE_2-OBJECT_1-NUMBER_OF_MASS_PROFILES-Y
# PLANE_2-OBJECT_1-HOST-Y
# PLANE_2-OBJECT_1-LIGHT_PROFILE_1-NAME-Y
# PLANE_2-OBJECT_1-LIGHT_PROFILE_1-magnitude-Y
# PLANE_2-OBJECT_1-LIGHT_PROFILE_1-center_x-Y
# PLANE_2-OBJECT_1-LIGHT_PROFILE_1-center_y-Y
# PLANE_2-OBJECT_1-LIGHT_PROFILE_1-R_sersic-Y
# PLANE_2-OBJECT_1-LIGHT_PROFILE_1-n_sersic-Y
# PLANE_2-OBJECT_1-LIGHT_PROFILE_1-e1-Y
# PLANE_2-OBJECT_1-LIGHT_PROFILE_1-e2-Y
# PLANE_2-OBJECT_1-MASS_PROFILE_1-NAME-Y
# PLANE_2-OBJECT_1-MASS_PROFILE_1-theta_E-Y
# PLANE_2-OBJECT_1-MASS_PROFILE_1-e1-Y
# PLANE_2-OBJECT_1-MASS_PROFILE_1-e2-Y
# PLANE_2-OBJECT_1-MASS_PROFILE_1-center_x-Y
# PLANE_2-OBJECT_1-MASS_PROFILE_1-center_y-Y
# PLANE_2-OBJECT_1-SHEAR_PROFILE_1-NAME-Y
# PLANE_2-OBJECT_1-SHEAR_PROFILE_1-gamma1-Y
# PLANE_2-OBJECT_1-SHEAR_PROFILE_1-gamma2-Y
# PLANE_2-OBJECT_2-NUMBER_OF_LIGHT_PROFILES-Y
# PLANE_2-OBJECT_2-NUMBER_OF_SHEAR_PROFILES-Y
# PLANE_2-OBJECT_2-NUMBER_OF_MASS_PROFILES-Y
# PLANE_2-OBJECT_2-HOST-Y
# PLANE_2-OBJECT_2-ra-Y
# PLANE_2-OBJECT_2-dec-Y
# PLANE_2-OBJECT_2-sep-Y
# PLANE_2-OBJECT_2-sep_unit-Y
# PLANE_2-OBJECT_2-magnitude-Y
# BACKGROUND_IDX-Y
# PLANE_1-REDSHIFT-g
# PLANE_2-REDSHIFT-g
# PLANE_1-REDSHIFT-r
# PLANE_2-REDSHIFT-r
# PLANE_1-REDSHIFT-i
# PLANE_2-REDSHIFT-i
# PLANE_1-REDSHIFT-z
# PLANE_2-REDSHIFT-z
# PLANE_1-REDSHIFT-Y
# PLANE_2-REDSHIFT-Y

# %% [markdown]
# Every individual number used in the `lenstronomy` simulation is tracked.

# %% [markdown]
# As well, the row index in the metadata dataframe corresponds to the image index in the image array, so you can track which image has which properties. The dataframe contents can be accessed like this:

# %%
dataset.CONFIGURATION_1_metadata.iloc[0:5]
# Out:
#    OBJID-g  H0-g  Om0-g  exposure_time-g  numPix-g  pixel_scale-g psf_type-g  \
# 0        1    70    0.3               90       100          0.263   GAUSSIAN
# 1        2    70    0.3               90       100          0.263   GAUSSIAN
# 2        3    70    0.3               90       100          0.263   GAUSSIAN
# 3        4    70    0.3               90       100          0.263   GAUSSIAN
# 4        5    70    0.3               90       100          0.263   GAUSSIAN
#
#    read_noise-g  ccd_gain-g  seeing-g  ...  PLANE_1-REDSHIFT-g  \
# 0             7       6.083       0.9  ...                 0.2
# 1             7       6.083       0.9  ...                 0.2
# 2             7       6.083       0.9  ...                 0.2
# 3             7       6.083       0.9  ...                 0.2
# 4             7       6.083       0.9  ...                 0.2
#
#    PLANE_2-REDSHIFT-g  PLANE_1-REDSHIFT-r  PLANE_2-REDSHIFT-r  \
# 0                 0.7                 0.2                 0.7
# 1                 0.7                 0.2                 0.7
# 2                 0.7                 0.2                 0.7
# 3                 0.7                 0.2                 0.7
# 4                 0.7                 0.2                 0.7
#
#   PLANE_1-REDSHIFT-i  PLANE_2-REDSHIFT-i PLANE_1-REDSHIFT-z  \
# 0                0.2                 0.7                0.2
# 1                0.2                 0.7                0.2
# 2                0.2                 0.7                0.2
# 3                0.2                 0.7                0.2
# 4                0.2                 0.7                0.2
#
#   PLANE_2-REDSHIFT-z  PLANE_1-REDSHIFT-Y  PLANE_2-REDSHIFT-Y
# 0                0.7                 0.2                 0.7
# 1                0.7                 0.2                 0.7
# 2                0.7                 0.2                 0.7
# 3                0.7                 0.2                 0.7
# 4                0.7                 0.2                 0.7
#
# [5 rows x 445 columns]

# %% [markdown]
# ## Saving Datasets
#
# If you are working in interactive mode, you can straightforwardly save the images array and metadata dataframe in any file format you are comfortable with.
#
# If you instead choose to set the `save_to_disk=True` option when making your dataset, let's look at what gets saved where.

# %%
saved_dataset = dl.make_dataset(config_file, save_to_disk=True)

# %% [markdown]
# Recall that the dataset object has the user-specified out directory as an attribute.

# %%
print(saved_dataset.outdir)

# %% [markdown]
# Let's look in that directory.

# %%
! ls MySimulationResults!

# %% [markdown]
# The image arrays have been stored as numpy files. They can be loaded by doing
# ```python
# images = numpy.load('MySimulationResults/CONFIGURATION_1_images.npy')
# ```
#
# The metadata dataframes have been written to csv files. They can be loaded by doing
# ```python
# metadata = pandas.read_csv('MySimulationResults/CONFIGURATION_1_metadata.csv')
# ```
#
# Future versions of `deeplenstronomy` will include file format flexibility and built in dataset loading funcitons.

# %% [markdown]
# ## The End
#
# That's pretty much it to generating datasets with `deeplenstronomy`! Feel free to contact me with any suggestions or bugs.
